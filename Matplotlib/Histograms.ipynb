# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
ml_stud_age=np.random.randint(18,45,100)
py_stud_age=np.random.randint(15,40,100)

# %%
ml_stud_age
# Out:
# array([24, 42, 20, 19, 34, 31, 38, 36, 26, 37, 33, 44, 38, 41, 42, 42, 31,
#        42, 36, 43, 31, 34, 31, 44, 29, 27, 25, 26, 36, 27, 35, 18, 37, 18,
#        35, 26, 41, 39, 34, 43, 41, 43, 44, 36, 39, 24, 38, 35, 34, 35, 28,
#        35, 32, 38, 27, 19, 39, 19, 37, 18, 21, 26, 28, 34, 32, 38, 20, 32,
#        38, 42, 43, 43, 32, 29, 19, 43, 20, 23, 44, 26, 43, 42, 36, 24, 39,
#        36, 30, 40, 39, 21, 22, 36, 25, 26, 34, 30, 44, 31, 37, 23])

# %%
py_stud_age
# Out:
# array([37, 17, 16, 35, 28, 18, 29, 37, 37, 19, 26, 32, 17, 20, 38, 32, 20,
#        30, 34, 26, 39, 19, 25, 31, 23, 37, 30, 27, 27, 34, 24, 36, 25, 19,
#        27, 34, 36, 36, 30, 38, 22, 16, 24, 24, 33, 37, 33, 24, 22, 25, 38,
#        28, 33, 32, 27, 27, 20, 20, 38, 15, 17, 23, 32, 16, 31, 39, 35, 25,
#        32, 33, 31, 17, 31, 28, 33, 29, 24, 21, 31, 34, 37, 38, 37, 16, 16,
#        19, 26, 25, 34, 39, 36, 33, 37, 37, 24, 22, 15, 32, 21, 20])

# %%
plt.hist(py_stud_age, rwidth=0.8,histtype='bar')
plt.title("PY students age")
plt.xlabel("Students age catagory")
plt.ylabel("No students age")
plt.show()

# %%
plt.hist(
    x,
    bins=None,
    range=None,
    density=False,
    weights=None,
    cumulative=False,
    bottom=None,
    histtype='bar',
    align='mid',
    orientation='vertical',
    rwidth=None,
    log=False,
    color=None,
    label=None,
    stacked=False,
    *,
    data=None,
# Out:
#   File "<ipython-input-13-00e946673b38>", line 17
#     *,
#      ^
# SyntaxError: invalid syntax

# %%
plt.hist(py_stud_age, rwidth=0.8,histtype='bar',orientation="horizontal",color="g")
plt.title("PY students age")
plt.xlabel("Students age catagory")
plt.ylabel("No students age")
plt.show()

# %%
plt.hist(py_stud_age, rwidth=0.8,histtype='bar',color="g")
plt.hist(ml_stud_age, rwidth=0.8,histtype='bar',color="y")
plt.title("PY students age")
plt.xlabel("Students age catagory")
plt.ylabel("No students age")
plt.legend(['PY Students'])
plt.show()

# %%
plt.hist(py_stud_age, rwidth=0.8,histtype='bar',color="g")
plt.title("PY students age")
plt.xlabel("Students age catagory")
plt.ylabel("No students age")
plt.legend(['PY Students'])
plt.show()

# %%
plt.hist([py_stud_age,ml_stud_age],rwidth=0.8,color=["g","y"])
plt.title("PY students age")
plt.xlabel("Students age catagory")
plt.ylabel("No students age")
plt.legend(['PY Students','ML Students age'])
plt.show()

# %%
plt.figure(figsize=(16,9))
plt.hist([py_stud_age,ml_stud_age],rwidth=0.8,color=["g","y"])
plt.title("PY students age")
plt.xlabel("Students age catagory")
plt.ylabel("No students age")
plt.legend(['PY Students','ML Students age'])
plt.show()

# %%
from matplotlib import style
style.use("ggplot")
plt.figure(figsize=(16,9))
plt.hist([py_stud_age,ml_stud_age],rwidth=0.8,color=["g","y"])
plt.title("PY-ML students age")
plt.xlabel("Students age catagory")
plt.ylabel("No students age")
plt.legend(['PY Students','ML Students age'])
plt.show()
